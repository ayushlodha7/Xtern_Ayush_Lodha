# %%
import pandas as pd, numpy as np
import requests
import json
import time

# %%
def get_data(keyword,loc=("39.7738797","-86.1784417"),  radius = "5000"):
  # API Key
  APIKEY = 'AIzaSyCPUAkr1Q_zfKt2uBED5tUYVaf5I2If9eo' 
  lat, lng = loc
  pagetoken = None
  # URL: Link + Lat + Lng + Radius + Type means keyword(Restaurant, Mall etc) + 
  url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&type={type}&key={APIKEY}{pagetoken}".format(lat = lat, lng = lng, radius = radius, 
                                                                                                                                                       type = keyword,APIKEY = APIKEY, 
                                                                                                                                                       pagetoken = "&pagetoken="+pagetoken 
                                                                                                                                                       if pagetoken else "")
  # print(url)
  response = requests.get(url)
  res = json.loads(response.text)
  # print(res)
  # print("here results ---->>> ", len(res["results"]))
  final_data = []
  for result in res["results"]:
    try:
      # Name of the place
      name = result['name']
      # Address of the place
      Add = result['vicinity']
      # Rating of the place
      rating = result['rating']
      # Types of the place associated with 
      types = result['types']
      data = [name, Add, rating, types, keyword]
      final_data.append(data)
    except:
      continue
  #create dataframe
  df = pd.DataFrame(final_data, columns=['Name','Address','Rating','types','keyword'])

  return(df)

# %%
df_1 = get_data(keyword="tourist_attraction",loc=("39.7738797","-86.1784417"),  radius = "5000")
df_2 = get_data(keyword="shopping_mall",loc=("39.7738797","-86.1784417"),  radius = "5000")
df_3 = get_data(keyword="art_gallery",loc=("39.7738797","-86.1784417"),  radius = "5000")
df_4 = get_data(keyword="restaurant",loc=("39.7738797","-86.1784417"),  radius = "5000")

# %%
df_1.head()
# Out:
#                                     Name  \
# 0                       Indianapolis Zoo
# 1                     Indiana Statehouse
# 2             Indiana Historical Society
# 3                       Eiteljorg Museum
# 4  The Children's Museum of Indianapolis
#
#                                      Address  Rating  \
# 0  1200 West Washington Street, Indianapolis     4.5
# 1   200 West Washington Street, Indianapolis     4.6
# 2         450 West Ohio Street, Indianapolis     4.7
# 3   500 West Washington Street, Indianapolis     4.6
# 4   3000 North Meridian Street, Indianapolis     4.7
#
#                                                types             keyword
# 0  [zoo, aquarium, tourist_attraction, point_of_i...  tourist_attraction
# 1  [tourist_attraction, local_government_office, ...  tourist_attraction
# 2  [tourist_attraction, museum, point_of_interest...  tourist_attraction
# 3  [tourist_attraction, museum, point_of_interest...  tourist_attraction
# 4  [tourist_attraction, museum, point_of_interest...  tourist_attraction

# %%
df_2.head()
# Out:
#                                         Name  \
# 0                         Circle Centre Mall
# 1                          West Side Shoppes
# 2  SHE. EVENT INDY CO - SHEXperience Shoppes
# 3                                 Sun Garage
# 4                                       INDY
#
#                                              Address  Rating  \
# 0              49 West Maryland Street, Indianapolis     4.1
# 1                     West 10th Street, Indianapolis     4.2
# 2  CIRCLE CENTRE MALL SHEXPERIENCE SHOPPES, 49 We...     4.8
# 3              48 West Maryland Street, Indianapolis     4.0
# 4       30 South Meridian Street # 650, Indianapolis     4.7
#
#                                                types        keyword
# 0  [shopping_mall, point_of_interest, establishment]  shopping_mall
# 1  [shopping_mall, point_of_interest, establishment]  shopping_mall
# 2  [shopping_mall, point_of_interest, establishment]  shopping_mall
# 3  [shopping_mall, point_of_interest, establishment]  shopping_mall
# 4  [shopping_mall, point_of_interest, establishment]  shopping_mall

# %%
df_3.head()
# Out:
#                              Name  \
# 0                    City Gallery
# 1           Cultural Arts Gallery
# 2               Nancy Lee Designs
# 3  Kurt Vonnegut Museum & Library
# 4                    LO-FI Lounge
#
#                                              Address  Rating  \
# 0           1505 North Delaware Street, Indianapolis     3.7
# 1  Room #148, 420 University Boulevard, Indianapolis     5.0
# 2           1125 East Brookside Avenue, Indianapolis     5.0
# 3                   543 Indiana Avenue, Indianapolis     4.8
# 4  G. C. Murphy Building, 1043 Virginia Avenue #2...     4.5
#
#                                                types      keyword
# 0    [art_gallery, point_of_interest, establishment]  art_gallery
# 1    [art_gallery, point_of_interest, establishment]  art_gallery
# 2  [art_gallery, jewelry_store, store, point_of_i...  art_gallery
# 3  [art_gallery, tourist_attraction, museum, libr...  art_gallery
# 4    [art_gallery, point_of_interest, establishment]  art_gallery

# %%
df_4.head()
# Out:
#                                Name                                  Address  \
# 0            Shapiro's Delicatessen  808 South Meridian Street, Indianapolis
# 1              St. Elmo Steak House  127 South Illinois Street, Indianapolis
# 2                   The Rathskeller   401 East Michigan Street, Indianapolis
# 3                    Harry & Izzy's  153 South Illinois Street, Indianapolis
# 4  Buca di Beppo Italian Restaurant   35 North Illinois Street, Indianapolis
#
#    Rating                                              types     keyword
# 0     4.5  [bakery, meal_takeaway, restaurant, food, poin...  restaurant
# 1     4.7  [night_club, bar, restaurant, food, point_of_i...  restaurant
# 2     4.5  [bar, restaurant, food, point_of_interest, est...  restaurant
# 3     4.7  [restaurant, food, point_of_interest, establis...  restaurant
# 4     4.1  [restaurant, food, point_of_interest, establis...  restaurant
