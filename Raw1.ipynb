# %%
APIKEY = 'AIzaSyCPUAkr1Q_zfKt2uBED5tUYVaf5I2If9eo' 
loc=("39.7738797","-86.1784417")
lat, lng = loc
type = "restaurant"
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&type={type}&key={APIKEY}{pagetoken}".format(lat = lat, lng = lng, radius = radius, type = type,APIKEY = APIKEY, pagetoken = "&pagetoken="+pagetoken if pagetoken else "")
print(url)
response = requests.get(url)
res = json.loads(response.text)
# print(res)
print("here results ---->>> ", len(res["results"]))

final_data = []
for result in res["results"]:
  name = result['name']
  Add = result['vicinity']
  rating = result['rating']
  types = result['types']

  data = [name, Add, rating, types]
  final_data.append(data)
df = pd.DataFrame(final_data, columns=['Name','Address','Rating','types'])
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.7738797,-86.1784417&radius=4000&type=restaurant&key=AIzaSyCPUAkr1Q_zfKt2uBED5tUYVaf5I2If9eo
# here results ---->>>  20

# %%
APIKEY = 'AIzaSyCPUAkr1Q_zfKt2uBED5tUYVaf5I2If9eo' 
loc=("39.7738797","-86.1784417")
lat, lng = loc
type = "tourist_attraction"
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&type={type}&key={APIKEY}{pagetoken}".format(lat = lat, lng = lng, radius = radius, type = type,APIKEY = APIKEY, pagetoken = "&pagetoken="+pagetoken if pagetoken else "")
print(url)
response = requests.get(url)
res = json.loads(response.text)
# print(res)
print("here results ---->>> ", len(res["results"]))

final_data = []
for result in res["results"]:
  name = result['name']
  Add = result['vicinity']
  rating = result['rating']
  types = result['types']

  data = [name, Add, rating, types]
  final_data.append(data)
df = pd.DataFrame(final_data, columns=['Name','Address','Rating','types'])
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.7738797,-86.1784417&radius=4000&type=tourist_attraction&key=AIzaSyCPUAkr1Q_zfKt2uBED5tUYVaf5I2If9eo
# here results ---->>>  20

# %%
df
# Out:
#                                                Name  \
# 0                                  Indianapolis Zoo
# 1                                Indiana Statehouse
# 2                        Indiana Historical Society
# 3                                  Eiteljorg Museum
# 4                     Indiana War Memorial & Museum
# 5                       Soldiers & Sailors Monument
# 6   Eugene and Marilyn Glick Indiana History Center
# 7                               White River Gardens
# 8               Benjamin Harrison Presidential Site
# 9                                     Easley Winery
# 10                               Holy Rosary Church
# 11                   Indiana Medical History Museum
# 12                       Saint Mary Catholic Church
# 13                        Saint John the Evangelist
# 14                             Indiana State Museum
# 15                         Rhythm! Discovery Center
# 16                   Kurt Vonnegut Museum & Library
# 17                Indianapolis Fire Fighters Museum
# 18                              The Children's Maze
# 19                           White River State Park
#
#                                               Address  Rating  \
# 0           1200 West Washington Street, Indianapolis     4.5
# 1            200 West Washington Street, Indianapolis     4.6
# 2                  450 West Ohio Street, Indianapolis     4.7
# 3            500 West Washington Street, Indianapolis     4.6
# 4               55 East Michigan Street, Indianapolis     4.7
# 5                     1 Monument Circle, Indianapolis     4.7
# 6                  450 West Ohio Street, Indianapolis     4.5
# 7           1200 West Washington Street, Indianapolis     4.7
# 8            1230 North Delaware Street, Indianapolis     4.7
# 9              205 North College Avenue, Indianapolis     4.7
# 10                   520 Stevens Street, Indianapolis     4.8
# 11                   3270 Kirkbride Way, Indianapolis     4.7
# 12          317 North New Jersey Street, Indianapolis     4.7
# 13              126 West Georgia Street, Indianapolis     4.8
# 14           650 West Washington Street, Indianapolis     4.6
# 15  Claypool Court Building, 110 West Washington S...     4.7
# 16                   543 Indiana Avenue, Indianapolis     4.8
# 17             748 Massachusetts Avenue, Indianapolis     4.8
# 18           801 West Washington Street, Indianapolis     4.1
# 19           801 West Washington Street, Indianapolis     4.7
#
#                                                 types
# 0   [zoo, tourist_attraction, aquarium, point_of_i...
# 1   [tourist_attraction, local_government_office, ...
# 2   [tourist_attraction, museum, point_of_interest...
# 3   [tourist_attraction, museum, point_of_interest...
# 4   [tourist_attraction, park, point_of_interest, ...
# 5   [tourist_attraction, point_of_interest, establ...
# 6   [tourist_attraction, library, museum, point_of...
# 7   [tourist_attraction, park, point_of_interest, ...
# 8   [tourist_attraction, museum, point_of_interest...
# 9   [tourist_attraction, food, point_of_interest, ...
# 10  [tourist_attraction, church, place_of_worship,...
# 11  [museum, tourist_attraction, point_of_interest...
# 12  [tourist_attraction, church, place_of_worship,...
# 13  [tourist_attraction, church, place_of_worship,...
# 14  [museum, tourist_attraction, store, point_of_i...
# 15  [museum, tourist_attraction, electronics_store...
# 16  [tourist_attraction, art_gallery, library, mus...
# 17  [museum, tourist_attraction, point_of_interest...
# 18  [park, tourist_attraction, point_of_interest, ...
# 19  [tourist_attraction, park, point_of_interest, ...
